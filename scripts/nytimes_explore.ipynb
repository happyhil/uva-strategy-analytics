# %%
import requests

# %%
import json

# %%
key = 'ekXkK00iXQSrmpnhsmLkQtxkBDps7q9q'
url = f'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key={key}'
response = requests.get(url=url)

# %%
results = json.loads(response.text)

# %%
results
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.',
#  'num_results': 20,
#  'results': [{'uri': 'nyt://article/a0bf8cb3-ba3b-5c14-8c8e-857907b5c624',
#    'url': 'https://www.nytimes.com/2021/03/02/books/dr-seuss-mulberry-street.html',
#    'id': 100000007631710,
#    'asset_id': 100000007631710,
#    'source': 'New York Times',
#    'published_date': '2021-03-02',
#    'updated': '2021-03-03 03:08:27',
#    'section': 'Books',
#    'subsection': '',
#    'nytdsection': 'books',
#    'adx_keywords': 'Books and Literature;Cartoons and Cartoonists;Discrimination;Race and Ethnicity;Geisel, Theodor Seuss;Dr Seuss Enterprises;PM (Newspaper);United States',
#    'column': None,
#    'byline': 'By Jenny Gross',
#    'type': 'Article',
#    'title': '6 Dr. Seuss Books Will No Longer Be Published Over Offensive Images',
# ...

# %%
url = f'https://api.nytimes.com/svc/mostpopular/v2/viewed/1.json?api-key={key}'

# %%
response = requests.get(url=url)

# %%
results = json.loads(response.text)

# %%
results
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2021 The New York Times Company.  All Rights Reserved.',
#  'num_results': 20,
#  'results': [{'uri': 'nyt://article/a0bf8cb3-ba3b-5c14-8c8e-857907b5c624',
#    'url': 'https://www.nytimes.com/2021/03/02/books/dr-seuss-mulberry-street.html',
#    'id': 100000007631710,
#    'asset_id': 100000007631710,
#    'source': 'New York Times',
#    'published_date': '2021-03-02',
#    'updated': '2021-03-03 03:08:27',
#    'section': 'Books',
#    'subsection': '',
#    'nytdsection': 'books',
#    'adx_keywords': 'Books and Literature;Cartoons and Cartoonists;Discrimination;Race and Ethnicity;Geisel, Theodor Seuss;Dr Seuss Enterprises;PM (Newspaper);United States',
#    'column': None,
#    'byline': 'By Jenny Gross',
#    'type': 'Article',
#    'title': '6 Dr. Seuss Books Will No Longer Be Published Over Offensive Images',
# ...
